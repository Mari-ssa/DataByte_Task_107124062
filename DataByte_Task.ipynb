# %% [markdown]
# ### Importing essential libraries

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow #to display image in google colab

# %% [markdown]
# ### Reading and display image

# %%
image=cv.imread(r"/content/image4.jpg")
blank=np.zeros(image.shape,dtype='uint8')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=920x518>

# %% [markdown]
# ### Convering image to grayscale

# %%
gray=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=920x518>

# %% [markdown]
# ### Marking diseased spots with white (Assuming diseased spot is less than healthy part)

# %%
black_count = np.sum(threshold_image == 0)
white_count = np.sum(threshold_image == 255)

# Now decide which thresholding to apply
if black_count > white_count:
    # More black → use inverted
    threshold_value, threshold_image = cv.threshold(gray, 100, 255, cv.THRESH_BINARY_INV)
else:
    # More white → use normal
    threshold_value, threshold_image = cv.threshold(gray, 100, 255, cv.THRESH_BINARY)

# Display the result
cv2_imshow(threshold_image)
# Out:
# <PIL.Image.Image image mode=L size=920x518>
